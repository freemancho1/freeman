# %% [markdown]
# # 간단한 GAN 모델

# %% [markdown]
# # 사전 준비

# %% [markdown]
# ## 라이브러리 불러오기

# %%
from ai.algorithms.gan import SimpleGAN
from utils.support_tf import LogLevelManager as llm
llm.set(2)

# %% [markdown]
# # 모델 생성

# %% [markdown]
# ## SimpleGAN class

# %% [markdown]
# ### 훈련 데이터 준비
#
# * GAN은 강화학습 개념으로 `레이블`이 필요없고, 시스템에서 일괄적으로 제공하는 `진짜`라는 레이블을 가지고 학습함

# %%
from tensorflow.keras.datasets.mnist import load_data

# 데이터 전처리(차원확장, 정규화 등)는 모델 클래스에서 직접 수행함
(train_x, _), (_, _) = load_data()

# %% [markdown]
# ### 모델 훈련

# %%
gan_hyper_parameter = {
    "epochs"            : 10000,
    "batch_size"        : 128,
    "latent_z_dim"      : 100,
    "num_display_log"   : 20,
}

try: 
    gan = SimpleGAN(train_x, **gan_hyper_parameter, tf_log_level=2)
    gan.fit()
    gan.display_last_generation_images()
except Exception as e:
    print(e)
# Out:
# 훈련시작: 2022-10-19 15:44:37.156385
# 데이터: Shape=(60000, 28, 28, 1), Epochs=10000, BatchSize=128
#    500( 1/20), [D loss: 0.029620, accuracy: 1.000000], [G loss: 0.029620], Time[Curr: 0:00:50.360813, Total: 0:00:52.745828, ETA: 2022-10-19 16:01:26.757716]
#   1000( 2/20), [D loss: 0.146084, accuracy: 0.960938], [G loss: 0.146084], Time[Curr: 0:00:46.496844, Total: 0:01:39.242672, ETA: 2022-10-19 16:00:13.342361]
#   1500( 3/20), [D loss: 0.305395, accuracy: 0.859375], [G loss: 0.305395], Time[Curr: 0:00:46.842148, Total: 0:02:26.084820, ETA: 2022-10-19 16:00:19.557827]
#   2000( 4/20), [D loss: 0.321139, accuracy: 0.855469], [G loss: 0.321139], Time[Curr: 0:00:46.250140, Total: 0:03:12.334960, ETA: 2022-10-19 16:00:09.493732]
#   2500( 5/20), [D loss: 0.603005, accuracy: 0.710938], [G loss: 0.603005], Time[Curr: 0:00:46.213531, Total: 0:03:58.548491, ETA: 2022-10-19 16:00:08.907896]
# ...

# %% [markdown]
# ### 숫자별 모델 훈련

# %% [markdown]
# #### 9

# %%
from tensorflow.keras.datasets.mnist import load_data
import numpy as np

(train_x, train_y), (_, _) = load_data()
train_x9 = train_x[np.where(train_y == 9)]

gan_hyper_parameter = {
    "epochs"            : 10000,
    "batch_size"        : 128,
    "latent_z_dim"      : 100,
    "num_display_log"   : 20,
}

try: 
    gan = SimpleGAN(train_x9, **gan_hyper_parameter, tf_log_level=2)
    gan.fit()
    gan.display_last_generation_images()
except Exception as e:
    print(e)
# Out:
# 훈련시작: 2022-10-19 16:32:47.904216
# 데이터: Shape=(5949, 28, 28, 1), Epochs=10000, BatchSize=128
#    500( 1/20), [D loss: 0.018240, accuracy: 1.000000], [G loss: 0.018240], Time[Curr: 0:00:48.065388, Total: 0:00:48.139705, ETA: 2022-10-19 16:48:49.286455]
#   1000( 2/20), [D loss: 0.064800, accuracy: 0.980469], [G loss: 0.064800], Time[Curr: 0:00:46.837285, Total: 0:01:34.976990, ETA: 2022-10-19 16:48:25.952522]
#   1500( 3/20), [D loss: 0.093361, accuracy: 0.960938], [G loss: 0.093361], Time[Curr: 0:00:45.976055, Total: 0:02:20.953045, ETA: 2022-10-19 16:48:10.450327]
#   2000( 4/20), [D loss: 1.352759, accuracy: 0.648438], [G loss: 1.352759], Time[Curr: 0:00:46.936559, Total: 0:03:07.889604, ETA: 2022-10-19 16:48:26.778955]
#   2500( 5/20), [D loss: 1.291878, accuracy: 0.652344], [G loss: 1.291878], Time[Curr: 0:00:46.944620, Total: 0:03:54.834224, ETA: 2022-10-19 16:48:26.907914]
# ...

# %% [markdown]
# ### 모든 숫자 각각 모델링

# %%
from ai.algorithms.gan_create_number import NumberGenerator

# %%
ng = NumberGenerator()

# %%
ng.fit_all()
# Out:
# 훈련 시작: 2022-10-20 10:40:10.719450
# 숫자 0 훈련
# 훈련시작: 2022-10-20 10:40:10.753237
# 데이터: Shape=(5923, 28, 28, 1), Epochs=20000, BatchSize=128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 ng.fit_all()
#
# File ~/projects/freeman/ai/algorithms/gan_create_number.py:38, in NumberGenerator.fit_all(self)
#      36 for i in range(10):
#      37     print(f"숫자 {i} 훈련")
# ---> 38     model = self.train(i)
#      39     with open(f"/home/freeman/projects/data/models/gan_digit/model{i}.pkl", "wb") as f:
#      40         pickle.dump(model, f)
#
# File ~/projects/freeman/ai/algorithms/gan_create_number.py:29, in NumberGenerator.train(self, digit)
#      24 train_x = self.data[np.where(self.label == digit)]
#      25 gan = SimpleGAN(train_x,
#      26                 epochs=self.epochs, batch_size=self.batch_size,
# ...

# %%
ng.generator(1,2,3,4)
# Out:
# gen_images: [array([[[250.89288   ],
#         [253.27455   ],
#         [229.18195   ],
#         [250.55391   ],
#         [  9.497393  ],
#         [  7.7309437 ],
#         [247.36554   ],
#         [ 11.25897   ],
#         [247.91457   ],
#         [  2.4401455 ],
#         [250.56242   ],
#         [252.7482    ],
#         [ 19.7641    ],
#         [ 57.84149   ],
#         [ 62.653614  ],
#         [ 79.1239    ],
#         [  8.81824   ],
#         [248.36206   ],
#         [253.43047   ],
#         [ 10.739258  ],
#         [217.00513   ],
#         [239.16046   ],
#         [ 11.697353  ],
#         [ 35.66102   ],
#         [  5.0172434 ],
#         [250.20721   ],
#         [163.44214   ],
#         [ 38.715923  ]],
#
#        [[238.4368    ],
#         [ 19.164349  ],
#         [  3.4831212 ],
#         [  2.1809537 ],
#         [118.31837   ],
#         [  2.6586185 ],
#         [251.90376   ],
#         [251.3618    ],
#         [ 31.073334  ],
# ...
